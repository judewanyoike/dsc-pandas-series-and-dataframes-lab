# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started
#
# Import the file `'turnstile_180901.txt'`.

# %%
# Import the required libraries
import pandas as pd # import tool to help with math functions
import matplotlib.pyplot as plt # imports tool to help with graphs for plotting
# %matplotlib inline   # enable displays of plots
# Out:
# UsageError: unrecognized arguments: # enable displays of plots

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt')# converts this csv file to pandas data frame

# Print the number of rows ans columns in df
print(df.shape) # shows rows and columns

# Print the first five rows of df
df.head()
# Out:
# (197625, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Rename all the columns to lower case:

# %%
# We can check and see what the columns look like with this code:
df.columns # shows all the columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
# Rename all the columns to lower case
df.columns=df.columns.str.lower()

# str.lower()--converts to small letter

# %%
# Now let's check and make sure that worked
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %%
df
# Out:
#          index    c/a  unit       scp        station linename division  \
# 0            0   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 1            1   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 2            2   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 3            3   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 4            4   A002  R051  02-00-00          59 ST  NQR456W      BMT
# ...        ...    ...   ...       ...            ...      ...      ...
# 197620  197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197621  197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197622  197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197623  197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197624  197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
#
#               date      time     desc  entries  \
# 0       08/25/2018  00:00:00  REGULAR  6736067
# ...

# %% [markdown]
# Change the index to `'linename'`:

# %%
# Change the index to 'linename'
df.set_index('linename', inplace=True) # simpliy bring line name column to beggining
df.columns
# Out:
# Index(['index', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %%
df
# Out:
#            index    c/a  unit       scp        station division        date  \
# linename
# NQR456W        0   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# NQR456W        1   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# NQR456W        2   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# NQR456W        3   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# NQR456W        4   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# ...          ...    ...   ...       ...            ...      ...         ...
# R         197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# R         197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# R         197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# R         197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# R         197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
#
#               time     desc  entries  \
# ...

# %% [markdown]
# Reset the index:

# %%
# Reset the index
df.reset_index(inplace=True) # resets the arrangements of the columns

# %%
df.head()
# Out:
#   linename  index   c/a  unit       scp station division        date  \
# 0  NQR456W      0  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 1  NQR456W      1  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 2  NQR456W      2  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 3  NQR456W      3  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 4  NQR456W      4  A002  R051  02-00-00   59 ST      BMT  08/25/2018
#
#        time     desc  entries  \
# 0  00:00:00  REGULAR  6736067
# 1  04:00:00  REGULAR  6736087
# 2  08:00:00  REGULAR  6736105
# 3  12:00:00  REGULAR  6736180
# 4  16:00:00  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Add a new 'num_lines' column
df['Num_Lines'] = df['linename'].apply(lambda x: len(set(x)))
df.sort_values(by='Num_Lines', ascending=False, inplace=True)

# %% [markdown]
# Write a function to clean column names:

# %%
my_set = set("112233")
print(my_set)
# set removes repetition
# Out:
# {'2', '1', '3'}

# %%
add_ten = lambda x: x + 10
print(add_ten(5))

# lambda x holds a function
# Out:
# 15

# %%
# Add a new 'num_lines' column
df['Num_Lines'] = df['linename'].apply(lambda x: len(set(x)))
df_sorted = df.sort_values(by='Num_Lines', ascending=True)
df_sorted.head()# show 1st 5 rows

# formula to sort in ascending:-
#                             df_name=df.sorted_values(by='Column_name_sorting', ascending=True)
# formula to sort in descending:-
#                             df_name=df.sorted_values(by='Column_name_sorting', ascending=False)
# formula to add column:-
#                             df['New_column_name']=df['column_whose_values you using']. apply(lambda x: len(set(x)))
# Out:
#        linename   index    c/a  unit       scp        station division  \
# 197624        R  197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 112615        1  112615  PTH04  R551  00-04-06   GROVE STREET      PTH
# 112579        1  112579  PTH04  R551  00-04-05   GROVE STREET      PTH
# 112562        1  112562  PTH04  R551  00-04-05   GROVE STREET      PTH
# 112563        1  112563  PTH04  R551  00-04-05   GROVE STREET      PTH
#
#              date      time     desc  entries  \
# 197624 2018-08-31  21:00:00  REGULAR     5554
# 112615 2018-08-29  11:29:41  REGULAR    18708
# 112579 2018-08-29  20:16:23  REGULAR    31883
# 112562 2018-08-26  20:52:23  REGULAR    28305
# 112563 2018-08-27  01:04:23  REGULAR    28318
#
#         exits                                                                 \
# 197624                                                348
# 112615                                               9144
# 112579                                              13597
# ...

# %%
# Before we start cleaning, let's look at what we've got

df.columns
# Out:
# Index(['linename', 'index', 'c/a', 'unit', 'scp', 'station', 'division',
#        'date', 'time', 'desc', 'entries',
#        'exits                                                               ',
#        'num_lines', 'day_of_week', 'Num_Lines'],
#       dtype='object')

# %%
def clean(col_name):
    # Clean the column name in any way you want to. Hint: think back to str methods 
    cleaned = df.columns.map(lambda col: col.lower())
    return cleaned

# %%
# Use the above function to clean the column names
df.columns=clean('Num_Lines')

# %%
# Check to ensure the column names were cleaned
df.columns
# Out:
# Index(['linename', 'index', 'c/a', 'unit', 'scp', 'station', 'division',
#        'date', 'time', 'desc', 'entries',
#        'exits                                                               ',
#        'num_lines', 'day_of_week', 'num_lines'],
#       dtype='object')

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
# Convert the data type of the 'date' column to a date
df['date'] = pd.to_datetime(df['date'])


# Add a new column 'day_of_week' that represents the day of the week 
df['day_of_week'] = df['date'].dt.day_name()

# %%
df['date']
# Out:
# 132292   2018-08-30
# 132255   2018-08-31
# 132253   2018-08-30
# 132414   2018-08-28
# 132412   2018-08-28
#             ...
# 181991   2018-08-28
# 181990   2018-08-27
# 181989   2018-08-27
# 181988   2018-08-27
# 197624   2018-08-31
# Name: date, Length: 197625, dtype: datetime64[ns]

# %%
df['day_of_week']
# Out:
# 132292    Thursday
# 132255      Friday
# 132253    Thursday
# 132414     Tuesday
# 132412     Tuesday
#             ...
# 181991     Tuesday
# 181990      Monday
# 181989      Monday
# 181988      Monday
# 197624      Friday
# Name: day_of_week, Length: 197625, dtype: object

# %%
# Group the data by day of week and plot the sum of the numeric columns
grouped = df.groupby('day_of_week').sum(numeric_only = True)
grouped.plot(kind='barh')
plt.show()

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
# Reset the index of grouped
grouped = grouped.reset_index()

# Print the first five rows of grouped
grouped.head()
# Out:
#   day_of_week       index        entries  \
# 0      Friday  2778112001  1110224700078
# 1      Monday  2783610827  1114237052454
# 2    Saturday  2741377942  1115661545514
# 3      Sunday  2792287000  1192306179082
# 4    Thursday  2817391725  1122723988662
#
#    exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
#
#    num_lines  num_lines
# 0      75573      75573
# 1      76110      76110
# 2      74725      74725
# 3      75306      75306
# 4      76607      76607

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# map()-function
days = pd.Series(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
day_map = {'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4}


numeric_days = days.map(day_map)

print(numeric_days)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
# Use this dictionary to create a new column 

weekend_map = {0: False, 1: False, 2: False, 3: False, 4: False, 5: True, 6: True}
day_of_week_map = {'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 
                  'Friday': 4, 'Saturday': 5, 'Sunday': 6}
grouped['day_of_week_num'] = grouped['day_of_week'].map(day_of_week_map)


# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map
grouped['is_weekend'] = grouped['day_of_week_num'].map(weekend_map)
pd.DataFrame(grouped['is_weekend'])
# Out:
#    is_weekend
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
# 5       False
# 6       False

# %%
grouped.columns = grouped.columns.str.strip()
grouped.columns
# Out:
# Index(['day_of_week', 'index', 'entries', 'exits', 'num_lines', 'num_lines',
#        'day_of_week_num', 'is_weekend'],
#       dtype='object')

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
wkend = grouped.groupby('is_weekend').sum(numeric_only = True)
wkend[['entries', 'exits']].plot(kind='barh')
plt.show()

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
# Remove the 'c/a' and 'scp' columns
df = df.drop(columns=['c/a', 'scp'])
df.head(2)
# Out:
#             linename   index  unit         station division       date  \
# 132292  1237ACENQRSW  132292  R033  TIMES SQ-42 ST      IRT 2018-08-30
# 132255  1237ACENQRSW  132255  R033  TIMES SQ-42 ST      IRT 2018-08-31
#
#             time     desc   entries  \
# 132292  00:00:00  REGULAR   1417952
# 132255  04:00:00  REGULAR  68217145
#
#         exits                                                                 \
# 132292                                            3267016
# 132255                                           17201834
#
#         num_lines day_of_week  num_lines
# 132292         12    Thursday         12
# 132255         12      Friday         12

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here

# %% [markdown]
# ## Summary
#
# You practiced your data cleanup skills using Pandas.
